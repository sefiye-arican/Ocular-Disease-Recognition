# %%
import tensorflow as tf
from tensorflow.keras.applications import VGG16
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
import matplotlib.pyplot as plt

# Veri dizinleri
train_dir = "/kaggle/input/clahe-esrgan-split-fundus-dataset/train"
test_dir = "/kaggle/input/clahe-esrgan-split-fundus-dataset/test"
img_size = (224, 224)
batch_size = 32
epochs = 50  # İlk eğitim için epoch sayısı

# Veri setlerini yükle
train_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    train_dir,
    image_size=img_size,
    batch_size=batch_size,
    label_mode='categorical',  # Etiketleri one-hot encode et
    shuffle=True,
    seed=42
)

test_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    test_dir,
    image_size=img_size,
    batch_size=batch_size,
    label_mode='categorical',  # Etiketleri one-hot encode et
    shuffle=False
)

from tensorflow.keras.layers import RandomFlip, RandomRotation, RandomZoom, RandomContrast

# Veri artırma (Data Augmentation) katmanları
data_augmentation = tf.keras.Sequential([
    RandomFlip("horizontal_and_vertical"),
    RandomRotation(0.2),
    RandomZoom(0.2),
    RandomContrast(0.2)
])



# Veri setine artırma uygula
train_dataset = train_dataset.map(
    lambda x, y: (data_augmentation(x, training=True), y)
)

# Normalizasyon katmanı
preprocess_input = tf.keras.applications.vgg16.preprocess_input

# Veri setine normalizasyon uygula
train_dataset = train_dataset.map(
    lambda x, y: (preprocess_input(x), y)
)
test_dataset = test_dataset.map(
    lambda x, y: (preprocess_input(x), y)
)

# Veri setlerini performans için optimize et
AUTOTUNE = tf.data.AUTOTUNE
train_dataset = train_dataset.prefetch(buffer_size=AUTOTUNE)
test_dataset = test_dataset.prefetch(buffer_size=AUTOTUNE)
# Out:
# Found 17524 files belonging to 8 classes.
# Found 4384 files belonging to 8 classes.

# %%
# VGG16 modelini yükle (transfer öğrenme)
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
base_model.trainable = False  # Başlangıçta katmanları dondur

# Model mimarisi
model = Sequential([
    base_model,
    GlobalAveragePooling2D(),
    Dense(256, activation='relu'),
    Dropout(0.5),
    Dense(train_dataset.element_spec[1].shape[1], activation='softmax')  # Sınıf sayısı
])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step

# %%
# Modeli derle
model.compile(optimizer=Adam(learning_rate=2e-4),  # learning_rate = 0.0002
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
model_checkpoint = ModelCheckpoint('vgg16_model.keras', save_best_only=True, monitor='val_accuracy')


# İlk eğitim (transfer öğrenme)
history = model.fit(
    train_dataset,
    epochs=epochs,
    validation_data=test_dataset,
    callbacks=[early_stopping, model_checkpoint]
)
# Out:
# Epoch 1/50
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 247s 431ms/step - accuracy: 0.5431 - loss: 2.1112 - val_accuracy: 0.8431 - val_loss: 0.4556
# Epoch 2/50
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 222s 404ms/step - accuracy: 0.8119 - loss: 0.6000 - val_accuracy: 0.8469 - val_loss: 0.4098
# Epoch 3/50
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 223s 407ms/step - accuracy: 0.8314 - loss: 0.5104 - val_accuracy: 0.8542 - val_loss: 0.3879
# Epoch 4/50
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 227s 414ms/step - accuracy: 0.8408 - loss: 0.4610 - val_accuracy: 0.8577 - val_loss: 0.3858
# Epoch 5/50
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 223s 406ms/step - accuracy: 0.8431 - loss: 0.4512 - val_accuracy: 0.8629 - val_loss: 0.3685
# Epoch 6/50
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 222s 404ms/step - accuracy: 0.8422 - loss: 0.4447 - val_accuracy: 0.8609 - val_loss: 0.3669
# Epoch 7/50
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 221s 403ms/step - accuracy: 0.8490 - loss: 0.4277 - val_accuracy: 0.8700 - val_loss: 0.3594
# Epoch 8/50
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 219s 399ms/step - accuracy: 0.8541 - loss: 0.4131 - val_accuracy: 0.8675 - val_loss: 0.3625
# Epoch 9/50
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 221s 403ms/step - accuracy: 0.8552 - loss: 0.4083 - val_accuracy: 0.8654 - val_loss: 0.3613
# Epoch 10/50
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 221s 402ms/step - accuracy: 0.8578 - loss: 0.3989 - val_accuracy: 0.8702 - val_loss: 0.3559
# Epoch 11/50
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 226s 412ms/step - accuracy: 0.8528 - loss: 0.3923 - val_accuracy: 0.8704 - val_loss: 0.3571
# Epoch 12/50
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 223s 407ms/step - accuracy: 0.8572 - loss: 0.3908 - val_accuracy: 0.8661 - val_loss: 0.3535
# Epoch 13/50
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 221s 402ms/step - accuracy: 0.8539 - loss: 0.3826 - val_accuracy: 0.8741 - val_loss: 0.3511
# Epoch 14/50
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 224s 408ms/step - accuracy: 0.8579 - loss: 0.3849 - val_accuracy: 0.8650 - val_loss: 0.3537
# Epoch 15/50
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 220s 401ms/step - accuracy: 0.8590 - loss: 0.3786 - val_accuracy: 0.8702 - val_loss: 0.3485
# Epoch 16/50
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 223s 406ms/step - accuracy: 0.8641 - loss: 0.3704 - val_accuracy: 0.8707 - val_loss: 0.3501
# Epoch 17/50
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 220s 401ms/step - accuracy: 0.8643 - loss: 0.3676 - val_accuracy: 0.8700 - val_loss: 0.3505
# Epoch 18/50
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 224s 409ms/step - accuracy: 0.8646 - loss: 0.3684 - val_accuracy: 0.8702 - val_loss: 0.3423
# Epoch 19/50
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 225s 411ms/step - accuracy: 0.8613 - loss: 0.3703 - val_accuracy: 0.8741 - val_loss: 0.3433
# Epoch 20/50
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 224s 409ms/step - accuracy: 0.8627 - loss: 0.3663 - val_accuracy: 0.8720 - val_loss: 0.3442
# Epoch 21/50
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 224s 408ms/step - accuracy: 0.8711 - loss: 0.3578 - val_accuracy: 0.8714 - val_loss: 0.3473
# Epoch 22/50
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 222s 404ms/step - accuracy: 0.8636 - loss: 0.3621 - val_accuracy: 0.8714 - val_loss: 0.3448
# Epoch 23/50
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 220s 401ms/step - accuracy: 0.8653 - loss: 0.3610 - val_accuracy: 0.8741 - val_loss: 0.3421
# Epoch 24/50
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 224s 408ms/step - accuracy: 0.8683 - loss: 0.3561 - val_accuracy: 0.8748 - val_loss: 0.3458
# Epoch 25/50
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 226s 412ms/step - accuracy: 0.8688 - loss: 0.3560 - val_accuracy: 0.8748 - val_loss: 0.3389
# Epoch 26/50
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 222s 405ms/step - accuracy: 0.8650 - loss: 0.3567 - val_accuracy: 0.8761 - val_loss: 0.3487
# Epoch 27/50
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 225s 409ms/step - accuracy: 0.8662 - loss: 0.3548 - val_accuracy: 0.8720 - val_loss: 0.3429
# Epoch 28/50
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 218s 397ms/step - accuracy: 0.8685 - loss: 0.3519 - val_accuracy: 0.8750 - val_loss: 0.3426
# Epoch 29/50
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 221s 403ms/step - accuracy: 0.8690 - loss: 0.3545 - val_accuracy: 0.8700 - val_loss: 0.3410
# Epoch 30/50
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 223s 406ms/step - accuracy: 0.8674 - loss: 0.3499 - val_accuracy: 0.8752 - val_loss: 0.3392
# Epoch 31/50
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 225s 411ms/step - accuracy: 0.8700 - loss: 0.3460 - val_accuracy: 0.8732 - val_loss: 0.3371
# Epoch 32/50
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 221s 403ms/step - accuracy: 0.8700 - loss: 0.3521 - val_accuracy: 0.8743 - val_loss: 0.3386
# Epoch 33/50
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 218s 397ms/step - accuracy: 0.8716 - loss: 0.3423 - val_accuracy: 0.8759 - val_loss: 0.3416
# Epoch 34/50
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 220s 400ms/step - accuracy: 0.8724 - loss: 0.3435 - val_accuracy: 0.8736 - val_loss: 0.3360
# Epoch 35/50
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 220s 401ms/step - accuracy: 0.8695 - loss: 0.3402 - val_accuracy: 0.8764 - val_loss: 0.3385
# Epoch 36/50
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 223s 406ms/step - accuracy: 0.8691 - loss: 0.3440 - val_accuracy: 0.8748 - val_loss: 0.3381
# Epoch 37/50
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 220s 401ms/step - accuracy: 0.8725 - loss: 0.3394 - val_accuracy: 0.8741 - val_loss: 0.3408
# Epoch 38/50
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 221s 403ms/step - accuracy: 0.8721 - loss: 0.3382 - val_accuracy: 0.8782 - val_loss: 0.3350
# Epoch 39/50
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 223s 407ms/step - accuracy: 0.8726 - loss: 0.3349 - val_accuracy: 0.8755 - val_loss: 0.3381
# Epoch 40/50
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 221s 403ms/step - accuracy: 0.8733 - loss: 0.3394 - val_accuracy: 0.8761 - val_loss: 0.3397
# Epoch 41/50
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 225s 410ms/step - accuracy: 0.8700 - loss: 0.3435 - val_accuracy: 0.8780 - val_loss: 0.3367
# Epoch 42/50
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 226s 412ms/step - accuracy: 0.8721 - loss: 0.3384 - val_accuracy: 0.8773 - val_loss: 0.3385
# Epoch 43/50
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 220s 400ms/step - accuracy: 0.8729 - loss: 0.3370 - val_accuracy: 0.8775 - val_loss: 0.3392
# Epoch 44/50
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 225s 411ms/step - accuracy: 0.8739 - loss: 0.3330 - val_accuracy: 0.8761 - val_loss: 0.3352
# Epoch 45/50
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 221s 402ms/step - accuracy: 0.8759 - loss: 0.3335 - val_accuracy: 0.8752 - val_loss: 0.3361
# Epoch 46/50
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 222s 404ms/step - accuracy: 0.8774 - loss: 0.3296 - val_accuracy: 0.8802 - val_loss: 0.3329
# Epoch 47/50
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 220s 400ms/step - accuracy: 0.8769 - loss: 0.3281 - val_accuracy: 0.8748 - val_loss: 0.3391
# Epoch 48/50
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 220s 402ms/step - accuracy: 0.8743 - loss: 0.3365 - val_accuracy: 0.8766 - val_loss: 0.3380
# Epoch 49/50
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 219s 399ms/step - accuracy: 0.8701 - loss: 0.3348 - val_accuracy: 0.8752 - val_loss: 0.3356
# Epoch 50/50
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 223s 406ms/step - accuracy: 0.8755 - loss: 0.3284 - val_accuracy: 0.8764 - val_loss: 0.3369

# %%
# Sonuçları görselleştir
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Eğitim Doğruluğu')
plt.plot(history.history['val_accuracy'], label='Doğrulama Doğruluğu')
plt.title('Model Doğruluğu')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Eğitim Kaybı')
plt.plot(history.history['val_loss'], label='Doğrulama Kaybı')
plt.title('Model Kaybı')
plt.legend()

plt.show()

# %%
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Test veri kümesini tahmin et
true_labels = []
predicted_labels = []

for images, labels in test_dataset:
    preds = model.predict(images)
    predicted_classes = np.argmax(preds, axis=1)
    true_classes = np.argmax(labels.numpy(), axis=1)

    predicted_labels.extend(predicted_classes)
    true_labels.extend(true_classes)

# Performans raporu
unique_classes = sorted(set(true_labels + predicted_labels))
target_names = [str(cls) for cls in unique_classes]
report = classification_report(true_labels, predicted_labels, target_names=target_names)
print("Classification Report:\n", report)

# Confusion matrix
cmp = confusion_matrix(true_labels, predicted_labels)
print("Confusion Matrix:\n", cmp)

# Confusion matrix'i görselleştir
plt.figure(figsize=(10, 7))
sns.heatmap(cmp, annot=True, fmt='d', cmap='Blues', xticklabels=target_names, yticklabels=target_names)
plt.xlabel('Tahmin Edilen')
plt.ylabel('Gerçek')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 544ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.99      0.92      0.95       535
#            1       0.98      0.99      0.99       532
#            2       0.83      0.62      0.71       584
#            3       0.98      0.91      0.94       534
#            4       1.00      0.97      0.98       520
#            5       1.00      0.98      0.99       528
#            6       0.57      0.93      0.71       600
#            7       0.98      0.76      0.85       551
#
#     accuracy                           0.88      4384
#    macro avg       0.92      0.88      0.89      4384
# weighted avg       0.91      0.88      0.88      4384
#
# Confusion Matrix:
#  [[490   1  11   2   0   0  30   1]
#  [  0 526   1   0   0   0   5   0]
#  [  1   0 360   3   0   1 217   2]
#  [  1   0   4 487   0   0  41   1]
#  [  0   0   4   0 504   0  12   0]
#  [  1   0   0   0   0 515  12   0]
#  [  1   3  25   6   0   0 560   5]
#  [  1   5  28   1   0   1  98 417]]

# %%
model.save('vgg_model.h5')

# %% [markdown]
# Attention

# %%
from tensorflow.keras.layers import Layer, GlobalAveragePooling2D, Reshape, Dense, Multiply, Add, Activation

class ChannelAttention(Layer):
    def __init__(self, ratio=8, **kwargs):
        super(ChannelAttention, self).__init__(**kwargs)
        self.ratio = ratio
        self.global_avg_pool = GlobalAveragePooling2D()
        self.global_max_pool = tf.reduce_max
        self.dense1 = Dense(units=1, activation='relu', kernel_initializer='he_normal', use_bias=False)
        self.dense2 = Dense(units=1, kernel_initializer='he_normal', use_bias=False)
        self.reshape = Reshape((1, 1, -1))
        self.add = Add()
        self.activation = Activation('sigmoid')
        self.multiply = Multiply()

    def call(self, inputs):
        channel = inputs.shape[-1]
        
        # Global Average Pooling
        avg_pool = self.global_avg_pool(inputs)
        avg_pool = self.reshape(avg_pool)
        
        # Global Max Pooling
        max_pool = tf.reduce_max(inputs, axis=[1, 2], keepdims=True)
        
        # Shared MLP
        avg_pool = self.dense1(avg_pool)
        max_pool = self.dense1(max_pool)
        
        avg_pool = self.dense2(avg_pool)
        max_pool = self.dense2(max_pool)
        
        # Add and Sigmoid
        channel_attention = self.add([avg_pool, max_pool])
        channel_attention = self.activation(channel_attention)
        
        return self.multiply([inputs, channel_attention])

# %%
from tensorflow.keras.layers import Conv2D, Concatenate

class SpatialAttention(Layer):
    def __init__(self, kernel_size=7, **kwargs):
        super(SpatialAttention, self).__init__(**kwargs)
        self.kernel_size = kernel_size
        self.concat = Concatenate(axis=-1)
        self.conv = Conv2D(filters=1, kernel_size=kernel_size, padding='same', activation='sigmoid', kernel_initializer='he_normal')
        self.multiply = Multiply()

    def call(self, inputs):
        # Average Pooling and Max Pooling along the channel axis
        avg_pool = tf.reduce_mean(inputs, axis=-1, keepdims=True)
        max_pool = tf.reduce_max(inputs, axis=-1, keepdims=True)
        
        # Concatenate along the channel axis
        concat = self.concat([avg_pool, max_pool])
        
        # Convolution layer
        spatial_attention = self.conv(concat)
        
        return self.multiply([inputs, spatial_attention])

# %%
from tensorflow.keras.models import Model

# VGG16 modelini yükle (transfer öğrenme)
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
base_model.trainable = False  # Başlangıçta katmanları dondur

# Base model'in çıktısını al
x = base_model.output

# Channel Attention ekle
x = ChannelAttention()(x)

# Spatial Attention ekle
x = SpatialAttention()(x)

# Global Average Pooling
x = GlobalAveragePooling2D()(x)

# Fully Connected Layer
x = Dense(256, activation='relu')(x)
x = Dropout(0.5)(x)

# Çıkış katmanı
output = Dense(train_dataset.element_spec[1].shape[1], activation='softmax')(x)

# Yeni modeli oluştur
model = Model(inputs=base_model.input, outputs=output)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
# Modeli derle
model.compile(optimizer=Adam(learning_rate=2e-4),  # learning_rate = 0.0002
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
model_checkpoint = ModelCheckpoint('vgg16_attention_model.keras', save_best_only=True, monitor='val_accuracy')

# İlk eğitim (transfer öğrenme)
history = model.fit(
    train_dataset,
    epochs=epochs,
    validation_data=test_dataset,
    callbacks=[early_stopping, model_checkpoint]
)
# Out:
# Epoch 1/50
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 252s 436ms/step - accuracy: 0.5726 - loss: 1.3112 - val_accuracy: 0.8504 - val_loss: 0.4440
# Epoch 2/50
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 222s 404ms/step - accuracy: 0.8317 - loss: 0.5431 - val_accuracy: 0.8650 - val_loss: 0.4011
# Epoch 3/50
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 221s 404ms/step - accuracy: 0.8396 - loss: 0.4743 - val_accuracy: 0.8672 - val_loss: 0.3868
# Epoch 4/50
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 222s 405ms/step - accuracy: 0.8486 - loss: 0.4357 - val_accuracy: 0.8702 - val_loss: 0.3718
# Epoch 5/50
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 226s 411ms/step - accuracy: 0.8491 - loss: 0.4309 - val_accuracy: 0.8714 - val_loss: 0.3651
# Epoch 6/50
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 221s 403ms/step - accuracy: 0.8512 - loss: 0.4172 - val_accuracy: 0.8729 - val_loss: 0.3612
# Epoch 7/50
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 222s 404ms/step - accuracy: 0.8591 - loss: 0.4029 - val_accuracy: 0.8684 - val_loss: 0.3620
# Epoch 8/50
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 219s 399ms/step - accuracy: 0.8568 - loss: 0.3995 - val_accuracy: 0.8718 - val_loss: 0.3581
# Epoch 9/50
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 222s 404ms/step - accuracy: 0.8578 - loss: 0.3913 - val_accuracy: 0.8725 - val_loss: 0.3552
# Epoch 10/50
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 224s 408ms/step - accuracy: 0.8599 - loss: 0.3830 - val_accuracy: 0.8723 - val_loss: 0.3495
# Epoch 11/50
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 221s 403ms/step - accuracy: 0.8625 - loss: 0.3745 - val_accuracy: 0.8716 - val_loss: 0.3518
# Epoch 12/50
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 222s 404ms/step - accuracy: 0.8618 - loss: 0.3786 - val_accuracy: 0.8745 - val_loss: 0.3463
# Epoch 13/50
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 220s 401ms/step - accuracy: 0.8639 - loss: 0.3690 - val_accuracy: 0.8743 - val_loss: 0.3448
# Epoch 14/50
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 221s 404ms/step - accuracy: 0.8660 - loss: 0.3641 - val_accuracy: 0.8711 - val_loss: 0.3487
# Epoch 15/50
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 224s 408ms/step - accuracy: 0.8665 - loss: 0.3593 - val_accuracy: 0.8720 - val_loss: 0.3451
# Epoch 16/50
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 225s 410ms/step - accuracy: 0.8634 - loss: 0.3683 - val_accuracy: 0.8736 - val_loss: 0.3426
# Epoch 17/50
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 223s 407ms/step - accuracy: 0.8690 - loss: 0.3580 - val_accuracy: 0.8766 - val_loss: 0.3453
# Epoch 18/50
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 220s 401ms/step - accuracy: 0.8693 - loss: 0.3545 - val_accuracy: 0.8752 - val_loss: 0.3419
# Epoch 19/50
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 221s 404ms/step - accuracy: 0.8701 - loss: 0.3510 - val_accuracy: 0.8743 - val_loss: 0.3444
# Epoch 20/50
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 222s 404ms/step - accuracy: 0.8694 - loss: 0.3543 - val_accuracy: 0.8752 - val_loss: 0.3411
# Epoch 21/50
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 224s 407ms/step - accuracy: 0.8661 - loss: 0.3508 - val_accuracy: 0.8709 - val_loss: 0.3428
# Epoch 22/50
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 223s 406ms/step - accuracy: 0.8712 - loss: 0.3477 - val_accuracy: 0.8755 - val_loss: 0.3405
# Epoch 23/50
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 224s 408ms/step - accuracy: 0.8684 - loss: 0.3441 - val_accuracy: 0.8736 - val_loss: 0.3373
# Epoch 24/50
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 224s 408ms/step - accuracy: 0.8736 - loss: 0.3441 - val_accuracy: 0.8761 - val_loss: 0.3370
# Epoch 25/50
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 222s 405ms/step - accuracy: 0.8695 - loss: 0.3417 - val_accuracy: 0.8757 - val_loss: 0.3363
# Epoch 26/50
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 221s 403ms/step - accuracy: 0.8719 - loss: 0.3378 - val_accuracy: 0.8734 - val_loss: 0.3411
# Epoch 27/50
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 220s 400ms/step - accuracy: 0.8754 - loss: 0.3410 - val_accuracy: 0.8775 - val_loss: 0.3350
# Epoch 28/50
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 219s 398ms/step - accuracy: 0.8722 - loss: 0.3398 - val_accuracy: 0.8752 - val_loss: 0.3401
# Epoch 29/50
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 220s 401ms/step - accuracy: 0.8730 - loss: 0.3376 - val_accuracy: 0.8771 - val_loss: 0.3402
# Epoch 30/50
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 221s 403ms/step - accuracy: 0.8719 - loss: 0.3378 - val_accuracy: 0.8741 - val_loss: 0.3347
# Epoch 31/50
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 222s 404ms/step - accuracy: 0.8738 - loss: 0.3353 - val_accuracy: 0.8766 - val_loss: 0.3341
# Epoch 32/50
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 219s 400ms/step - accuracy: 0.8730 - loss: 0.3355 - val_accuracy: 0.8768 - val_loss: 0.3363
# Epoch 33/50
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 219s 399ms/step - accuracy: 0.8764 - loss: 0.3283 - val_accuracy: 0.8777 - val_loss: 0.3337
# Epoch 34/50
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 221s 403ms/step - accuracy: 0.8752 - loss: 0.3253 - val_accuracy: 0.8768 - val_loss: 0.3348
# Epoch 35/50
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 223s 407ms/step - accuracy: 0.8712 - loss: 0.3350 - val_accuracy: 0.8766 - val_loss: 0.3358
# Epoch 36/50
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 218s 398ms/step - accuracy: 0.8725 - loss: 0.3291 - val_accuracy: 0.8759 - val_loss: 0.3344
# Epoch 37/50
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 220s 402ms/step - accuracy: 0.8759 - loss: 0.3295 - val_accuracy: 0.8768 - val_loss: 0.3384
# Epoch 38/50
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 221s 403ms/step - accuracy: 0.8727 - loss: 0.3361 - val_accuracy: 0.8768 - val_loss: 0.3348
# Epoch 39/50
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 221s 403ms/step - accuracy: 0.8760 - loss: 0.3263 - val_accuracy: 0.8805 - val_loss: 0.3324
# Epoch 40/50
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 222s 404ms/step - accuracy: 0.8765 - loss: 0.3273 - val_accuracy: 0.8791 - val_loss: 0.3326
# Epoch 41/50
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 221s 403ms/step - accuracy: 0.8744 - loss: 0.3293 - val_accuracy: 0.8771 - val_loss: 0.3316
# Epoch 42/50
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 220s 401ms/step - accuracy: 0.8774 - loss: 0.3285 - val_accuracy: 0.8773 - val_loss: 0.3311
# Epoch 43/50
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 221s 403ms/step - accuracy: 0.8806 - loss: 0.3236 - val_accuracy: 0.8729 - val_loss: 0.3363
# Epoch 44/50
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 219s 400ms/step - accuracy: 0.8792 - loss: 0.3205 - val_accuracy: 0.8782 - val_loss: 0.3332
# Epoch 45/50
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 222s 405ms/step - accuracy: 0.8781 - loss: 0.3234 - val_accuracy: 0.8802 - val_loss: 0.3341
# Epoch 46/50
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 223s 407ms/step - accuracy: 0.8803 - loss: 0.3133 - val_accuracy: 0.8809 - val_loss: 0.3321
# Epoch 47/50
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 219s 400ms/step - accuracy: 0.8798 - loss: 0.3150 - val_accuracy: 0.8771 - val_loss: 0.3343
# Epoch 48/50
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 220s 401ms/step - accuracy: 0.8798 - loss: 0.3147 - val_accuracy: 0.8775 - val_loss: 0.3368
# Epoch 49/50
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 218s 397ms/step - accuracy: 0.8776 - loss: 0.3209 - val_accuracy: 0.8766 - val_loss: 0.3341
# Epoch 50/50
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 222s 404ms/step - accuracy: 0.8822 - loss: 0.3136 - val_accuracy: 0.8773 - val_loss: 0.3337

# %%
# Sonuçları görselleştir
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Eğitim Doğruluğu')
plt.plot(history.history['val_accuracy'], label='Doğrulama Doğruluğu')
plt.title('Model Doğruluğu')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Eğitim Kaybı')
plt.plot(history.history['val_loss'], label='Doğrulama Kaybı')
plt.title('Model Kaybı')
plt.legend()

plt.show()

# %%
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Test veri kümesini tahmin et
true_labels = []
predicted_labels = []

for images, labels in test_dataset:
    preds = model.predict(images)
    predicted_classes = np.argmax(preds, axis=1)
    true_classes = np.argmax(labels.numpy(), axis=1)

    predicted_labels.extend(predicted_classes)
    true_labels.extend(true_classes)

# Performans raporu
unique_classes = sorted(set(true_labels + predicted_labels))
target_names = [str(cls) for cls in unique_classes]
report = classification_report(true_labels, predicted_labels, target_names=target_names)
print("Classification Report:\n", report)

# Confusion matrix
cmp = confusion_matrix(true_labels, predicted_labels)
print("Confusion Matrix:\n", cmp)

# Confusion matrix'i görselleştir
plt.figure(figsize=(10, 7))
sns.heatmap(cmp, annot=True, fmt='d', cmap='Blues', xticklabels=target_names, yticklabels=target_names)
plt.xlabel('Tahmin Edilen')
plt.ylabel('Gerçek')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 788ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      0.92      0.96       535
#            1       0.98      0.98      0.98       532
#            2       0.76      0.66      0.71       584
#            3       0.97      0.91      0.94       534
#            4       1.00      0.97      0.98       520
#            5       0.99      0.98      0.98       528
#            6       0.59      0.88      0.71       600
#            7       0.97      0.75      0.85       551
#
#     accuracy                           0.88      4384
#    macro avg       0.91      0.88      0.89      4384
# weighted avg       0.90      0.88      0.88      4384
#
# Confusion Matrix:
#  [[491   1  12   2   0   0  26   3]
#  [  0 523   1   0   0   0   7   1]
#  [  1   1 385   2   0   2 190   3]
#  [  0   0  10 485   0   0  39   0]
#  [  0   0   5   0 504   0  11   0]
#  [  0   0   3   0   0 515  10   0]
#  [  0   4  49  11   0   1 527   8]
#  [  1   5  43   1   0   1  84 416]]

# %%
model.save('vgg_att_model.h5')
